# %%
#imports
import numpy as np
import pandas as pd
import spacy

# %%
dataframe_letras = pd.read_csv('letras.csv', header = 0, names = ['Titulo', 'Letra', 'Artista'])
dataframe_letras
# Out:
#                                      Titulo  \
# 0                            A Louca Chegou
# 1                            A Luz da Light
# 2                      Abrigo de Vagabundos
# 3                        Acende O Candieiro
# 4                             Adeus, Escola
# ..                                      ...
# 320           Vou Botar Teu Nome Na Macumba
# 321                   Vou Procurar Esquecer
# 322                         Vou Ver Juliana
# 323  Yaô Cadê A Samba / Outro Recado / Hino
# 324                        Zeca, Cadê Você?
#
#                                                  Letra           Artista
# 0    A louca chegou o ô, a louca chegou Desesperada...  adoniran-barbosa
# 1    Lá no morro quando a luz da light pífa A gente...  adoniran-barbosa
# 2    Eu arranjei o meu dinheiro Trabalhando o ano i...  adoniran-barbosa
# 3    Falado:  "Vai nêga, fala que o pai mandou, viu...  adoniran-barbosa
# 4    Enganado eu vou partir Neste mundo jamais vive...  adoniran-barbosa
# ..                                                 ...               ...
# 320  Eu vou botar teu nome na macumba Vou procurar ...    zeca-pagodinho
# 321  Vou procurar um novo amor na minha vida Porque...    zeca-pagodinho
# 322  Quando a mare vazá Vou vê juliana Vou vê julia...    zeca-pagodinho
# 323  Ô Yaô Yaô, cadê a samba? Está mangando na curi...    zeca-pagodinho
# 324  Ô, Zeca, tu tá morando onde? Ô, Zeca, tu tá mo...    zeca-pagodinho
#
# [14695 rows x 3 columns]

# %%
# nlp - tokenizacao
nlp = spacy.load('pt_core_news_lg')

dataframe_letras['letras_tokens'] = [nlp(cancao) for cancao in dataframe_letras.Letra]
dataframe_letras.sample(3)
# Out:
#                Titulo                                              Letra  \
# 122  Na Sombra da Lua  Hoje eu quero ser conforme a lua Passar toda n...
# 25               Rosa  Tu és, divina e graciosa Estátua majestosa do ...
# 274    Noite de Verão  Este não sou eu Meus lábios nos seus lábios nã...
#
#            Artista                                      letras_tokens
# 122          agepe  (Hoje, eu, quero, ser, conforme, a, lua, Passa...
# 25     pixinguinha  (Tu, és, ,, divina, e, graciosa, Estátua, maje...
# 274  chico-buarque  (Este, não, sou, eu, Meus, lábios, nos, seus, ...

# %%
# lemmatizacao - removendo stop words
stop_words = nlp.Defaults.stop_words
FIRST_TEN = 10
palavras_lemmatizadas = []
for doc in dataframe_letras['letras_tokens']:
    for token in doc:
        if token.text not in stop_words and token.pos_ in ['NOUN', 'VERB']:
            palavras_lemmatizadas.append(token.lemma_.lower())
print(f'Foram lemmatizadas {len(palavras_lemmatizadas)} palavras.')
print(palavras_lemmatizadas[:FIRST_TEN])
# Out:
# Foram lemmatizadas 630689 palavras.
# ['louca', 'chegar', 'louca', 'chegar', 'desesperada', 'procurar', 'amor', 'louca', 'chegar', 'louca']

# %%
# gerando wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud
unique_string = (' ').join(palavras_lemmatizadas)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize = (15,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('wordcloud'+'.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
import gensim
from gensim.models import KeyedVectors
from gensim.models import Word2Vec

lista_lista_tokens = [[letras] for letras in palavras_lemmatizadas]
modelo_skipgram = Word2Vec(window = 5, sg = 1, min_count = 1, alpha = 0.03, min_alpha = 0.007)
modelo_skipgram.build_vocab(lista_lista_tokens, progress_per=5000)

modelo_skipgram.train(lista_lista_tokens, 
                     total_examples = modelo_skipgram.corpus_count,
                     epochs = 30)
# Out:
# (17119504, 18920670)

# %%
modelo_skipgram.wv.most_similar('samba')
# Out:
# [('introd', 0.4340824484825134),
#  ('parlamento', 0.3744429647922516),
#  ('berinjela', 0.3589790165424347),
#  ('panturrilha', 0.35621029138565063),
#  ('bamba-querer', 0.35059884190559387),
#  ('comunhão', 0.34068307280540466),
#  ('sério', 0.3403392434120178),
#  ('obrigacao', 0.33453959226608276),
#  ('esgarçam', 0.33244937658309937),
#  ('iludor', 0.3318939805030823)]
